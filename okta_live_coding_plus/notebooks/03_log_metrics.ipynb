# %% [markdown]
# # Log Metrics — Walkthrough

# %%
from problems._wrappers import m_03_log_metrics as mod
lines=['status=200 latency_ms=100','status=500 latency_ms=900','status=200 latency_ms=600']
mod.compute_metrics(lines, slow_threshold_ms=500)
