# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# 🚀 LLM Learning Notebook\n",
    "\n",
    "This template uses a global setup: `from utils.notebook_setup import client`.\n",
    "- Client points to local Ollama (`http://localhost:11434/v1`)\n",
    "- Project root is auto-added to `sys.path`\n",
    "- CWD is set to the project root (can be disabled via `NOTEBOOK_FORCE_PROJECT_CWD=0`)\n",
    "\n",
    "---"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "# 🔧 Minimal setup (do not modify)\n",
    "from utils.notebook_setup import client\n",
    "print(\"✅ Client imported from notebook_setup\")"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 🔍 Quick Test"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "r = client.chat.completions.create(\n",
    "    model=\"llama3.2:3b\",  # small & fast\n",
    "    messages=[{\"role\": \"user\", \"content\": \"Say hello in one sentence.\"}],\n",
    ")\n",
    "print(r.choices[0].message.content)"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 📚 Lesson Prompts"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "from utils.helper_functions import get_llm_response, print_llm_response\n",
    "\n",
    "txt = get_llm_response(\n",
    "    client,\n",
    "    \"Explain embeddings in 3 beginner-friendly bullets.\",\n",
    "    model=\"llama3\",\n",
    "    system=\"You are a clear and concise teacher.\",\n",
    "    temperature=0.2,\n",
    ")\n",
    "print_llm_response(txt)"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## ✍️ Notes\n",
    "- Key points:\n",
    "- Open questions:\n",
    "- Follow-ups:"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## ✅ Reflection\n",
    "- How can I apply this at work?\n",
    "- What was confusing?\n",
    "- What’s next?"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 5
}
# Out:
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {},
#    'source': ['# 🚀 LLM Learning Notebook\n',
#     '\n',
#     'This template uses a global setup: `from utils.notebook_setup import client`.\n',
#     '- Client points to local Ollama (`http://localhost:11434/v1`)\n',
#     '- Project root is auto-added to `sys.path`\n',
#     '- CWD is set to the project root (can be disabled via `NOTEBOOK_FORCE_PROJECT_CWD=0`)\n',
#     '\n',
#     '---']},
#   {'cell_type': 'code',
#    'metadata': {},
#    'source': ['# 🔧 Minimal setup (do not modify)\n',
#     'from utils.notebook_setup import client\n',
#     'print("✅ Client imported from notebook_setup")']},
#   {'cell_type': 'markdown', 'metadata': {}, 'source': ['## 🔍 Quick Test']},
#   {'cell_type': 'code',
#    'metadata': {},
#    'source': ['r = client.chat.completions.create(\n',
#     '    model="llama3.2:3b",  # small & fast\n',
#     '    messages=[{"role": "user", "content": "Say hello in one sentence."}],\n',
# ...
